# %%
import os
import pcapy as p
from scapy.all import *
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import time
import struct

# %%
data = np.load("8s_data.npz")["data"]
t = np.array(np.load("8s_data.npz")["t"])
t = t - min(t)
T = [t[x+1]-t[x] for x in range(len(t)-1)]
len(data)*len(data[0])/(t[-1]-t[0])/1024/1024,"Mo/s"
# Out:
# (3.8559204217867067, 'Mo/s')

# %%
plt.plot(T[0:550])
